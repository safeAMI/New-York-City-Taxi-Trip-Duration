# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv("../data/train.csv", index_col = 0)
test_df = pd.read_csv("../data/test.csv", index_col = 0)

# %%
#import pandas_profiling as ppf
#ppf.ProfileReport(train_df)

# %%
train_df.head(10)
# Out:
#            vendor_id      pickup_datetime     dropoff_datetime  \
# id
# id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# id0801584          2  2016-01-30 22:01:40  2016-01-30 22:09:03
# id1813257          1  2016-06-17 22:34:59  2016-06-17 22:40:40
# id1324603          2  2016-05-21 07:54:58  2016-05-21 08:20:49
# id1301050          1  2016-05-27 23:12:23  2016-05-27 23:16:38
# id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
#
#            passenger_count  pickup_longitude  pickup_latitude  \
# id
# id2875421                1        -73.982155        40.767937
# id2377394                1        -73.980415        40.738564
# id3858529                1        -73.979027        40.763939
# id3504673                1        -74.010040        40.719971
# id2181028                1        -73.973053        40.793209
# id0801584                6        -73.982857        40.742195
# id1813257                4        -73.969017        40.757839
# id1324603                1        -73.969276        40.797779
# id1301050                1        -73.999481        40.738400
# id0012891                1        -73.981049        40.744339
#
#            dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# id
# id2875421         -73.964630         40.765602                  N
# id2377394         -73.999481         40.731152                  N
# id3858529         -74.005333         40.710087                  N
# id3504673         -74.012268         40.706718                  N
# id2181028         -73.972923         40.782520                  N
# id0801584         -73.992081         40.749184                  N
# id1813257         -73.957405         40.765896                  N
# id1324603         -73.922470         40.760559                  N
# id1301050         -73.985786         40.732815                  N
# id0012891         -73.973000         40.789989                  N
#
#            trip_duration
# id
# id2875421            455
# id2377394            663
# id3858529           2124
# id3504673            429
# id2181028            435
# id0801584            443
# id1813257            341
# id1324603           1551
# id1301050            255
# id0012891           1225

# %%
test_df.head()
# Out:
#            vendor_id      pickup_datetime  passenger_count  pickup_longitude  \
# id
# id3004672          1  2016-06-30 23:59:58                1        -73.988129
# id3505355          1  2016-06-30 23:59:53                1        -73.964203
# id1217141          1  2016-06-30 23:59:47                1        -73.997437
# id2150126          2  2016-06-30 23:59:41                1        -73.956070
# id1598245          1  2016-06-30 23:59:33                1        -73.970215
#
#            pickup_latitude  dropoff_longitude  dropoff_latitude  \
# id
# id3004672        40.732029         -73.990173         40.756680
# id3505355        40.679993         -73.959808         40.655403
# id1217141        40.737583         -73.986160         40.729523
# id2150126        40.771900         -73.986427         40.730469
# id1598245        40.761475         -73.961510         40.755890
#
#           store_and_fwd_flag
# id
# id3004672                  N
# id3505355                  N
# id1217141                  N
# id2150126                  N
# id1598245                  N

# %%
# %matplotlib inline
trip_duration = pd.DataFrame({"trip_duration":train_df["trip_duration"], "log(trip_duration + 1)":np.log1p(train_df["trip_duration"])})
trip_duration.hist()
# Out:
# array([[<AxesSubplot:title={'center':'trip_duration'}>,
#         <AxesSubplot:title={'center':'log(trip_duration + 1)'}>]],
#       dtype=object)

# %%
y_train = np.log1p(train_df.pop('trip_duration'))

# %%
#train_df.pop("dropoff_datetime")
# Out:
# id
# id2875421    2016-03-14 17:32:30
# id2377394    2016-06-12 00:54:38
# id3858529    2016-01-19 12:10:48
# id3504673    2016-04-06 19:39:40
# id2181028    2016-03-26 13:38:10
#                     ...
# id2376096    2016-04-08 13:44:02
# id1049543    2016-01-10 07:46:10
# id2304944    2016-04-22 07:10:25
# id2714485    2016-01-05 16:02:39
# id1209952    2016-04-05 14:47:43
# Name: dropoff_datetime, Length: 1458644, dtype: object

# %%
#train_df.shape, test_df.shape
# Out:
# ((1458644, 8), (625134, 8))

# %%
all_df = pd.concat((train_df,test_df), axis=0)

# %%
#all_df['vendor_id'].value_counts()
#all_df['pickup_datetime'] = all_df['pickup_datetime'].astype(str)
all_df['vendor_id'] = all_df['vendor_id'].astype(str)

# %%
all_df["pickup_datetime"]
# Out:
# id
# id2875421    2016-03-14 17:24:55
# id2377394    2016-06-12 00:43:35
# id3858529    2016-01-19 11:35:24
# id3504673    2016-04-06 19:32:31
# id2181028    2016-03-26 13:30:55
#                     ...
# id3008929    2016-01-01 00:02:52
# id3700764    2016-01-01 00:01:52
# id2568735    2016-01-01 00:01:24
# id1384355    2016-01-01 00:00:28
# id0621643    2016-01-01 00:00:22
# Name: pickup_datetime, Length: 2083778, dtype: object

# %%
new_cols = all_df['pickup_datetime'].str.split(' ', 2, True)

# %%
new_cols.columns = ["date", "time"]

# %%
new_cols
# Out:
#                  date      time
# id
# id2875421  2016-03-14  17:24:55
# id2377394  2016-06-12  00:43:35
# id3858529  2016-01-19  11:35:24
# id3504673  2016-04-06  19:32:31
# id2181028  2016-03-26  13:30:55
# ...               ...       ...
# id3008929  2016-01-01  00:02:52
# id3700764  2016-01-01  00:01:52
# id2568735  2016-01-01  00:01:24
# id1384355  2016-01-01  00:00:28
# id0621643  2016-01-01  00:00:22
#
# [2083778 rows x 2 columns]

# %%
all_df.pop("pickup_datetime")
# Out:
# id
# id2875421    2016-03-14 17:24:55
# id2377394    2016-06-12 00:43:35
# id3858529    2016-01-19 11:35:24
# id3504673    2016-04-06 19:32:31
# id2181028    2016-03-26 13:30:55
#                     ...
# id3008929    2016-01-01 00:02:52
# id3700764    2016-01-01 00:01:52
# id2568735    2016-01-01 00:01:24
# id1384355    2016-01-01 00:00:28
# id0621643    2016-01-01 00:00:22
# Name: pickup_datetime, Length: 2083778, dtype: object

# %%
new_time = new_cols["time"].str.split(':', 3, True)

# %%
new_time.columns = ["hour","minute","second"]

# %%
new_time
# Out:
#           hour minute second
# id
# id2875421   17     24     55
# id2377394   00     43     35
# id3858529   11     35     24
# id3504673   19     32     31
# id2181028   13     30     55
# ...        ...    ...    ...
# id3008929   00     02     52
# id3700764   00     01     52
# id2568735   00     01     24
# id1384355   00     00     28
# id0621643   00     00     22
#
# [2083778 rows x 3 columns]

# %%
new_date = new_cols["date"].str.split('-', 3, True)
new_date.columns = ["year","month","day"]

# %%
new_date, new_time
# Out:
# (           year month day
#  id
#  id2875421  2016    03  14
#  id2377394  2016    06  12
#  id3858529  2016    01  19
#  id3504673  2016    04  06
#  id2181028  2016    03  26
#  ...         ...   ...  ..
#  id3008929  2016    01  01
#  id3700764  2016    01  01
#  id2568735  2016    01  01
#  id1384355  2016    01  01
#  id0621643  2016    01  01
#
#  [2083778 rows x 3 columns],           hour minute second
#  id
#  id2875421   17     24     55
#  id2377394   00     43     35
#  id3858529   11     35     24
#  id3504673   19     32     31
#  id2181028   13     30     55
#  ...        ...    ...    ...
#  id3008929   00     02     52
#  id3700764   00     01     52
#  id2568735   00     01     24
#  id1384355   00     00     28
#  id0621643   00     00     22
#
#  [2083778 rows x 3 columns])

# %%
all_df
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# id
# id2875421         2                1        -73.982155        40.767937
# id2377394         1                1        -73.980415        40.738564
# id3858529         2                1        -73.979027        40.763939
# id3504673         2                1        -74.010040        40.719971
# id2181028         2                1        -73.973053        40.793209
# ...             ...              ...               ...              ...
# id3008929         1                1        -74.003464        40.725105
# id3700764         1                1        -74.006363        40.743782
# id2568735         1                2        -73.972267        40.759865
# id1384355         1                1        -73.976501        40.733562
# id0621643         2                2        -73.981850        40.716881
#
#            dropoff_longitude  dropoff_latitude store_and_fwd_flag
# id
# id2875421         -73.964630         40.765602                  N
# id2377394         -73.999481         40.731152                  N
# id3858529         -74.005333         40.710087                  N
# id3504673         -74.012268         40.706718                  N
# id2181028         -73.972923         40.782520                  N
# ...                      ...               ...                ...
# id3008929         -74.001251         40.733643                  N
# id3700764         -73.953407         40.782467                  N
# id2568735         -73.876602         40.748665                  N
# id1384355         -73.854263         40.891788                  N
# id0621643         -73.969330         40.769379                  N
#
# [2083778 rows x 7 columns]

# %%
all_df.isnull().sum().sort_values(ascending=False).head(10) #无缺失值
# Out:
# store_and_fwd_flag    0
# dropoff_latitude      0
# dropoff_longitude     0
# pickup_latitude       0
# pickup_longitude      0
# passenger_count       0
# vendor_id             0
# dtype: int64

# %%
all_df['store_and_fwd_flag'].dtypes
# Out:
# dtype('O')

# %%
all_df_pt = pd.concat((all_df,new_time), axis=1)

# %%
all_df_pt = pd.concat((all_df,new_date), axis=1)

# %%
all_df_pt.pop("year")
# Out:
# id
# id2875421    2016
# id2377394    2016
# id3858529    2016
# id3504673    2016
# id2181028    2016
#              ...
# id3008929    2016
# id3700764    2016
# id2568735    2016
# id1384355    2016
# id0621643    2016
# Name: year, Length: 2083778, dtype: object

# %%
all_df_pt
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# id
# id2875421         2                1        -73.982155        40.767937
# id2377394         1                1        -73.980415        40.738564
# id3858529         2                1        -73.979027        40.763939
# id3504673         2                1        -74.010040        40.719971
# id2181028         2                1        -73.973053        40.793209
# ...             ...              ...               ...              ...
# id3008929         1                1        -74.003464        40.725105
# id3700764         1                1        -74.006363        40.743782
# id2568735         1                2        -73.972267        40.759865
# id1384355         1                1        -73.976501        40.733562
# id0621643         2                2        -73.981850        40.716881
#
#            dropoff_longitude  dropoff_latitude store_and_fwd_flag month day
# id
# id2875421         -73.964630         40.765602                  N    03  14
# id2377394         -73.999481         40.731152                  N    06  12
# id3858529         -74.005333         40.710087                  N    01  19
# id3504673         -74.012268         40.706718                  N    04  06
# id2181028         -73.972923         40.782520                  N    03  26
# ...                      ...               ...                ...   ...  ..
# id3008929         -74.001251         40.733643                  N    01  01
# id3700764         -73.953407         40.782467                  N    01  01
# id2568735         -73.876602         40.748665                  N    01  01
# id1384355         -73.854263         40.891788                  N    01  01
# id0621643         -73.969330         40.769379                  N    01  01
#
# [2083778 rows x 9 columns]

# %%
all_new_datetime = pd.concat((new_date,new_time), axis=1)

# %%
all_new_datetime
# Out:
#            year month day hour minute second
# id
# id2875421  2016    03  14   17     24     55
# id2377394  2016    06  12   00     43     35
# id3858529  2016    01  19   11     35     24
# id3504673  2016    04  06   19     32     31
# id2181028  2016    03  26   13     30     55
# ...         ...   ...  ..  ...    ...    ...
# id3008929  2016    01  01   00     02     52
# id3700764  2016    01  01   00     01     52
# id2568735  2016    01  01   00     01     24
# id1384355  2016    01  01   00     00     28
# id0621643  2016    01  01   00     00     22
#
# [2083778 rows x 6 columns]

# %%
all_df_pt = pd.concat((all_df,all_new_datetime), axis=1)

# %%
all_df_pt
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# id
# id2875421         2                1        -73.982155        40.767937
# id2377394         1                1        -73.980415        40.738564
# id3858529         2                1        -73.979027        40.763939
# id3504673         2                1        -74.010040        40.719971
# id2181028         2                1        -73.973053        40.793209
# ...             ...              ...               ...              ...
# id3008929         1                1        -74.003464        40.725105
# id3700764         1                1        -74.006363        40.743782
# id2568735         1                2        -73.972267        40.759865
# id1384355         1                1        -73.976501        40.733562
# id0621643         2                2        -73.981850        40.716881
#
#            dropoff_longitude  dropoff_latitude store_and_fwd_flag  year month  \
# id
# id2875421         -73.964630         40.765602                  N  2016    03
# id2377394         -73.999481         40.731152                  N  2016    06
# id3858529         -74.005333         40.710087                  N  2016    01
# id3504673         -74.012268         40.706718                  N  2016    04
# id2181028         -73.972923         40.782520                  N  2016    03
# ...                      ...               ...                ...   ...   ...
# id3008929         -74.001251         40.733643                  N  2016    01
# id3700764         -73.953407         40.782467                  N  2016    01
# id2568735         -73.876602         40.748665                  N  2016    01
# id1384355         -73.854263         40.891788                  N  2016    01
# id0621643         -73.969330         40.769379                  N  2016    01
#
#           day hour minute second
# id
# id2875421  14   17     24     55
# id2377394  12   00     43     35
# id3858529  19   11     35     24
# id3504673  06   19     32     31
# id2181028  26   13     30     55
# ...        ..  ...    ...    ...
# id3008929  01   00     02     52
# id3700764  01   00     01     52
# id2568735  01   00     01     24
# id1384355  01   00     00     28
# id0621643  01   00     00     22
#
# [2083778 rows x 13 columns]

# %%
all_df_pt.pop('year')
# Out:
# id
# id2875421    2016
# id2377394    2016
# id3858529    2016
# id3504673    2016
# id2181028    2016
#              ...
# id3008929    2016
# id3700764    2016
# id2568735    2016
# id1384355    2016
# id0621643    2016
# Name: year, Length: 2083778, dtype: object

# %%
all_df_pt['month'].dtype
# Out:
# dtype('O')

# %%
#all_df_pt['month'] = all_df_pt['month'].astype(str)
all_df_pt['month'].value_counts()
# Out:
# 03    365886
# 04    359077
# 05    356057
# 02    340614
# 06    334761
# 01    327383
# Name: month, dtype: int64

# %%
pd.get_dummies(all_df_pt['month'], prefix='month').head()
all_dummy_df = pd.get_dummies(all_df_pt)
all_dummy_df.head()
# Out:
#            passenger_count  pickup_longitude  pickup_latitude  \
# id
# id2875421                1        -73.982155        40.767937
# id2377394                1        -73.980415        40.738564
# id3858529                1        -73.979027        40.763939
# id3504673                1        -74.010040        40.719971
# id2181028                1        -73.973053        40.793209
#
#            dropoff_longitude  dropoff_latitude  vendor_id_1  vendor_id_2  \
# id
# id2875421         -73.964630         40.765602            0            1
# id2377394         -73.999481         40.731152            1            0
# id3858529         -74.005333         40.710087            0            1
# id3504673         -74.012268         40.706718            0            1
# id2181028         -73.972923         40.782520            0            1
#
#            store_and_fwd_flag_N  store_and_fwd_flag_Y  month_01  ...  \
# id                                                               ...
# id2875421                     1                     0         0  ...
# id2377394                     1                     0         0  ...
# id3858529                     1                     0         1  ...
# id3504673                     1                     0         0  ...
# id2181028                     1                     0         0  ...
#
#            second_50  second_51  second_52  second_53  second_54  second_55  \
# id
# id2875421          0          0          0          0          0          1
# id2377394          0          0          0          0          0          0
# id3858529          0          0          0          0          0          0
# id3504673          0          0          0          0          0          0
# id2181028          0          0          0          0          0          1
#
#            second_56  second_57  second_58  second_59
# id
# id2875421          0          0          0          0
# id2377394          0          0          0          0
# id3858529          0          0          0          0
# id3504673          0          0          0          0
# id2181028          0          0          0          0
#
# [5 rows x 190 columns]

# %%
#标准化数据
numeric_cols = all_df.columns[all_df.dtypes != 'object']
numeric_cols
# Out:
# Index(['passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude'],
#       dtype='object')

# %%
numeric_col_means = all_dummy_df.loc[:, numeric_cols].mean()
numeric_col_std = all_dummy_df.loc[:, numeric_cols].std()
all_dummy_df.loc[:, numeric_cols] = (all_dummy_df.loc[:, numeric_cols] - numeric_col_means) / numeric_col_std

# %%
dummy_train_df = all_dummy_df.loc[train_df.index]
dummy_test_df = all_dummy_df.loc[test_df.index]

# %%
X_train = dummy_train_df.values
X_test = dummy_test_df.values

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

# %%
#alphas = np.logspace(-3, 2, 50)
#test_scores = []
#for alpha in alphas:
    #clf = Ridge(alpha)
    #test_score = np.sqrt(-cross_val_score(clf, X_train, y_train, cv=10, scoring='neg_mean_squared_error'))
    #test_scores.append(np.mean(test_score))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.plot(alphas, test_scores)
#plt.title("Alpha vs CV Error");

# %%
from sklearn.ensemble import RandomForestRegressor
#max_features = [.1, .3, .5, .7, .9, .99]
#test_scores = []
#for max_feat in max_features:
    #clf = RandomForestRegressor(n_estimators=200, max_features=max_feat)
    #test_score = np.sqrt(-cross_val_score(clf, X_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    #test_scores.append(np.mean(test_score))
#plt.plot(max_features, test_scores)
#plt.title("Max Features vs CV Error");

# %%
ridge = Ridge(alpha=15)
rf = RandomForestRegressor(n_estimators=500, max_features=.3)

# %%
ridge.fit(X_train, y_train)
rf.fit(X_train, y_train)
y_ridge = np.expm1(ridge.predict(X_test))
y_rf = np.expm1(rf.predict(X_test))

# %%
y_final = (y_ridge + y_rf) / 2

# %%
submission_df = pd.DataFrame(data= {'Id' : test_df.index, 'SalePrice': y_final})
